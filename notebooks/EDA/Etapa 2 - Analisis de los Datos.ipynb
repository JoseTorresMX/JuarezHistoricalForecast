# %% [markdown]
# # 3. Visualización de los datos

# %%
# Lectura del dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Lectura del CSV
ruta_csv="..//../csv/WHData_Cd_Juarez.csv"

# Leyendo CSV con Pandas
datajuarez=pd.read_csv(ruta_csv, encoding='latin-1')

#Mostra dataframe
print(datajuarez.shape)
datajuarez.head(10)
# Out:
# (209424, 21)
#         location        date     v_10u     v_10v      v_2d       v_2t  \
# 0  Ciudad Juarez  01/01/2000 -1.669281 -0.020920  7.480493  17.317834
# 1  Ciudad Juarez  01/01/2000 -1.951294 -0.468689  8.055566  16.767297
# 2  Ciudad Juarez  01/01/2000 -1.763443 -0.294388  5.953119  14.243799
# 3  Ciudad Juarez  01/01/2000 -1.436081  0.382751  5.892938  11.471796
# 4  Ciudad Juarez  01/01/2000 -0.908798  1.725983  5.761438  11.316980
# 5  Ciudad Juarez  01/01/2000 -0.377380  2.554306  5.132959   9.031458
# 6  Ciudad Juarez  01/01/2000  0.356659  2.629395  4.263757   7.635492
# 7  Ciudad Juarez  01/01/2000  1.176437  2.084335  3.994012   7.308130
# 8  Ciudad Juarez  01/01/2000  1.626434  1.169067  4.224725   7.595605
# 9  Ciudad Juarez  01/01/2000  1.527802  0.984741  4.503931   7.604150
#
#          v_cbh           v_e   v_i10fg         v_mer  ...        v_msl  \
# 0  1907.450439 -7.220000e-06  2.148321 -2.000000e-06  ...  1012.635625
# 1  2135.849121 -1.550000e-06  2.747254 -4.300000e-07  ...  1012.456250
# 2  2208.853027 -4.540000e-07  2.561296 -1.230000e-07  ...  1012.368125
# 3  7484.599609  3.110000e-07  2.200583  8.660000e-08  ...  1012.543125
# 4          NaN  6.010000e-07  2.526732  1.660000e-07  ...  1012.673750
# 5          NaN  1.440000e-06  3.777871  3.940000e-07  ...  1012.659375
# 6          NaN  2.260000e-06  4.538428  6.250000e-07  ...  1012.491250
# 7  2290.968262  1.700000e-06  4.661475  4.710000e-07  ...  1012.315000
# 8  2288.184326  2.120000e-06  4.536755  5.900000e-07  ...  1012.189375
# 9  2202.159912  1.690000e-06  4.077042  4.710000e-07  ...  1011.985000
#
#           v_pev              v_ptype     v_stl1   v_swvl1     v_tcc  v_tp  \
# 0 -1.250000e-05  sin precipitaciones  13.064264  0.137127  0.152496   0.0
# 1 -6.860000e-07  sin precipitaciones  12.453210  0.137084  0.236725   0.0
# 2  6.660000e-07  sin precipitaciones  10.392664  0.137066  0.579987   0.0
# 3  1.220000e-06  sin precipitaciones   8.273584  0.137028  0.482239   0.0
# 4  1.130000e-06  sin precipitaciones   7.544336  0.137005  0.411499   0.0
# 5  2.290000e-06  sin precipitaciones   6.913049  0.136968  0.614685   0.0
# 6  3.490000e-06  sin precipitaciones   6.220911  0.136947  0.535614   0.0
# 7  2.970000e-06  sin precipitaciones   5.943872  0.136921  0.141052   0.0
# 8  3.070000e-06  sin precipitaciones   5.993433  0.136891  0.577209   0.0
# 9  2.480000e-06  sin precipitaciones   5.963464  0.136874  0.652557   0.0
#
#    v_wa      v_wd      v_ws
# 0    89      este  1.669412
# 1    76      este  2.006793
# 2    81      este  1.787847
# 3   105      este  1.486212
# 4   152   sureste  1.950623
# 5   172       sur  2.582033
# 6   188       sur  2.653473
# 7   209  sudoeste  2.393420
# 8   234  sudoeste  2.003000
# 9   237  sudoeste  1.817661
#
# [10 rows x 21 columns]

# %% [markdown]
# # 4. Limpieza
# En este apartado se realiza la limpieza del dataset, se realizaran:
#
# 1. Reemplazo de valores, si es que lo necesitan.
# 2. Tranformar valores para que sean comprensibles.
# 2. Reemplazo de las cabeceras, si es que lo necesitan.

# %%
print(datajuarez.shape)
datajuarez.head(10)
# Out:
# (209424, 21)
#         location        date     v_10u     v_10v      v_2d       v_2t  \
# 0  Ciudad Juarez  01/01/2000 -1.669281 -0.020920  7.480493  17.317834
# 1  Ciudad Juarez  01/01/2000 -1.951294 -0.468689  8.055566  16.767297
# 2  Ciudad Juarez  01/01/2000 -1.763443 -0.294388  5.953119  14.243799
# 3  Ciudad Juarez  01/01/2000 -1.436081  0.382751  5.892938  11.471796
# 4  Ciudad Juarez  01/01/2000 -0.908798  1.725983  5.761438  11.316980
# 5  Ciudad Juarez  01/01/2000 -0.377380  2.554306  5.132959   9.031458
# 6  Ciudad Juarez  01/01/2000  0.356659  2.629395  4.263757   7.635492
# 7  Ciudad Juarez  01/01/2000  1.176437  2.084335  3.994012   7.308130
# 8  Ciudad Juarez  01/01/2000  1.626434  1.169067  4.224725   7.595605
# 9  Ciudad Juarez  01/01/2000  1.527802  0.984741  4.503931   7.604150
#
#          v_cbh           v_e   v_i10fg         v_mer  ...        v_msl  \
# 0  1907.450439 -7.220000e-06  2.148321 -2.000000e-06  ...  1012.635625
# 1  2135.849121 -1.550000e-06  2.747254 -4.300000e-07  ...  1012.456250
# 2  2208.853027 -4.540000e-07  2.561296 -1.230000e-07  ...  1012.368125
# 3  7484.599609  3.110000e-07  2.200583  8.660000e-08  ...  1012.543125
# 4          NaN  6.010000e-07  2.526732  1.660000e-07  ...  1012.673750
# 5          NaN  1.440000e-06  3.777871  3.940000e-07  ...  1012.659375
# 6          NaN  2.260000e-06  4.538428  6.250000e-07  ...  1012.491250
# 7  2290.968262  1.700000e-06  4.661475  4.710000e-07  ...  1012.315000
# 8  2288.184326  2.120000e-06  4.536755  5.900000e-07  ...  1012.189375
# 9  2202.159912  1.690000e-06  4.077042  4.710000e-07  ...  1011.985000
#
#           v_pev              v_ptype     v_stl1   v_swvl1     v_tcc  v_tp  \
# 0 -1.250000e-05  sin precipitaciones  13.064264  0.137127  0.152496   0.0
# 1 -6.860000e-07  sin precipitaciones  12.453210  0.137084  0.236725   0.0
# 2  6.660000e-07  sin precipitaciones  10.392664  0.137066  0.579987   0.0
# 3  1.220000e-06  sin precipitaciones   8.273584  0.137028  0.482239   0.0
# 4  1.130000e-06  sin precipitaciones   7.544336  0.137005  0.411499   0.0
# 5  2.290000e-06  sin precipitaciones   6.913049  0.136968  0.614685   0.0
# 6  3.490000e-06  sin precipitaciones   6.220911  0.136947  0.535614   0.0
# 7  2.970000e-06  sin precipitaciones   5.943872  0.136921  0.141052   0.0
# 8  3.070000e-06  sin precipitaciones   5.993433  0.136891  0.577209   0.0
# 9  2.480000e-06  sin precipitaciones   5.963464  0.136874  0.652557   0.0
#
#    v_wa      v_wd      v_ws
# 0    89      este  1.669412
# 1    76      este  2.006793
# 2    81      este  1.787847
# 3   105      este  1.486212
# 4   152   sureste  1.950623
# 5   172       sur  2.582033
# 6   188       sur  2.653473
# 7   209  sudoeste  2.393420
# 8   234  sudoeste  2.003000
# 9   237  sudoeste  1.817661
#
# [10 rows x 21 columns]

# %%
# Reemplzando titulos de las cabeceras para hacerlos mas legibles
nuevos_titulos = {'location': 'ubicacion',
                  'date': 'fecha',
                  'v_10u': 'viento_U',
                  'v_10v': 'viento_V',
                  'v_2d': 'pto_rocio',
                  'v_2t': 'tem_viento',
                  'v_cbh': 'alt_nube',
                  'v_e': 'evaporacion',
                  'v_i10fg': 'rafaga_viento',
                  'v_mer': 'evap_media',
                  'v_mper': 'evap_media_potencial',
                  'v_msl': 'pm_nivel_del_mar',
                  'v_pev': 'evap_potencial',
                  'v_ptype': 'tip_precipitacion',
                  'v_stl1': 'temp_del_suelo',
                  'v_swvl1': 'agua_del_suelo',
                  'v_tcc': 'nubosidad',
                  'v_tp': 'precip_acum_x_hora',
                  'v_wa': 'angulo_viento',
                  'v_wd': 'dir_viento',
                  'v_ws': 'vel_viento'}

print("Dataframe nueva cabecera:\n")
datajuarez = datajuarez.rename(columns=nuevos_titulos)
datajuarez.head(10)
# Out:
# Dataframe nueva cabecera:
#        ubicacion       fecha  viento_U  viento_V  pto_rocio  tem_viento  \
# 0  Ciudad Juarez  01/01/2000 -1.669281 -0.020920   7.480493   17.317834
# 1  Ciudad Juarez  01/01/2000 -1.951294 -0.468689   8.055566   16.767297
# 2  Ciudad Juarez  01/01/2000 -1.763443 -0.294388   5.953119   14.243799
# 3  Ciudad Juarez  01/01/2000 -1.436081  0.382751   5.892938   11.471796
# 4  Ciudad Juarez  01/01/2000 -0.908798  1.725983   5.761438   11.316980
# 5  Ciudad Juarez  01/01/2000 -0.377380  2.554306   5.132959    9.031458
# 6  Ciudad Juarez  01/01/2000  0.356659  2.629395   4.263757    7.635492
# 7  Ciudad Juarez  01/01/2000  1.176437  2.084335   3.994012    7.308130
# 8  Ciudad Juarez  01/01/2000  1.626434  1.169067   4.224725    7.595605
# 9  Ciudad Juarez  01/01/2000  1.527802  0.984741   4.503931    7.604150
#
#       alt_nube   evaporacion  rafaga_viento    evap_media  ...  \
# 0  1907.450439 -7.220000e-06       2.148321 -2.000000e-06  ...
# 1  2135.849121 -1.550000e-06       2.747254 -4.300000e-07  ...
# 2  2208.853027 -4.540000e-07       2.561296 -1.230000e-07  ...
# 3  7484.599609  3.110000e-07       2.200583  8.660000e-08  ...
# 4          NaN  6.010000e-07       2.526732  1.660000e-07  ...
# 5          NaN  1.440000e-06       3.777871  3.940000e-07  ...
# 6          NaN  2.260000e-06       4.538428  6.250000e-07  ...
# 7  2290.968262  1.700000e-06       4.661475  4.710000e-07  ...
# 8  2288.184326  2.120000e-06       4.536755  5.900000e-07  ...
# 9  2202.159912  1.690000e-06       4.077042  4.710000e-07  ...
#
#    pm_nivel_del_mar  evap_potencial    tip_precipitacion temp_del_suelo  \
# 0       1012.635625   -1.250000e-05  sin precipitaciones      13.064264
# 1       1012.456250   -6.860000e-07  sin precipitaciones      12.453210
# 2       1012.368125    6.660000e-07  sin precipitaciones      10.392664
# 3       1012.543125    1.220000e-06  sin precipitaciones       8.273584
# 4       1012.673750    1.130000e-06  sin precipitaciones       7.544336
# 5       1012.659375    2.290000e-06  sin precipitaciones       6.913049
# 6       1012.491250    3.490000e-06  sin precipitaciones       6.220911
# 7       1012.315000    2.970000e-06  sin precipitaciones       5.943872
# 8       1012.189375    3.070000e-06  sin precipitaciones       5.993433
# 9       1011.985000    2.480000e-06  sin precipitaciones       5.963464
#
#    agua_del_suelo  nubosidad  precip_acum_x_hora  angulo_viento  dir_viento  \
# 0        0.137127   0.152496                 0.0             89        este
# 1        0.137084   0.236725                 0.0             76        este
# 2        0.137066   0.579987                 0.0             81        este
# 3        0.137028   0.482239                 0.0            105        este
# 4        0.137005   0.411499                 0.0            152     sureste
# 5        0.136968   0.614685                 0.0            172         sur
# 6        0.136947   0.535614                 0.0            188         sur
# 7        0.136921   0.141052                 0.0            209    sudoeste
# 8        0.136891   0.577209                 0.0            234    sudoeste
# 9        0.136874   0.652557                 0.0            237    sudoeste
#
#   vel_viento
# 0   1.669412
# 1   2.006793
# 2   1.787847
# 3   1.486212
# 4   1.950623
# 5   2.582033
# 6   2.653473
# 7   2.393420
# 8   2.003000
# 9   1.817661
#
# [10 rows x 21 columns]

# %% [markdown]
# ## 4.2 Columnas irrelevantes

# %%
print("Dimensiones del Dataframe:\n",datajuarez.shape)
datajuarez.head(10)
# Out:
# Dimensiones del Dataframe:
#  (209424, 21)
#        ubicacion       fecha  viento_U  viento_V  pto_rocio  tem_viento  \
# 0  Ciudad Juarez  01/01/2000 -1.669281 -0.020920   7.480493   17.317834
# 1  Ciudad Juarez  01/01/2000 -1.951294 -0.468689   8.055566   16.767297
# 2  Ciudad Juarez  01/01/2000 -1.763443 -0.294388   5.953119   14.243799
# 3  Ciudad Juarez  01/01/2000 -1.436081  0.382751   5.892938   11.471796
# 4  Ciudad Juarez  01/01/2000 -0.908798  1.725983   5.761438   11.316980
# 5  Ciudad Juarez  01/01/2000 -0.377380  2.554306   5.132959    9.031458
# 6  Ciudad Juarez  01/01/2000  0.356659  2.629395   4.263757    7.635492
# 7  Ciudad Juarez  01/01/2000  1.176437  2.084335   3.994012    7.308130
# 8  Ciudad Juarez  01/01/2000  1.626434  1.169067   4.224725    7.595605
# 9  Ciudad Juarez  01/01/2000  1.527802  0.984741   4.503931    7.604150
#
#       alt_nube   evaporacion  rafaga_viento    evap_media  ...  \
# 0  1907.450439 -7.220000e-06       2.148321 -2.000000e-06  ...
# 1  2135.849121 -1.550000e-06       2.747254 -4.300000e-07  ...
# 2  2208.853027 -4.540000e-07       2.561296 -1.230000e-07  ...
# 3  7484.599609  3.110000e-07       2.200583  8.660000e-08  ...
# 4          NaN  6.010000e-07       2.526732  1.660000e-07  ...
# 5          NaN  1.440000e-06       3.777871  3.940000e-07  ...
# 6          NaN  2.260000e-06       4.538428  6.250000e-07  ...
# 7  2290.968262  1.700000e-06       4.661475  4.710000e-07  ...
# 8  2288.184326  2.120000e-06       4.536755  5.900000e-07  ...
# 9  2202.159912  1.690000e-06       4.077042  4.710000e-07  ...
#
#    pm_nivel_del_mar  evap_potencial    tip_precipitacion temp_del_suelo  \
# 0       1012.635625   -1.250000e-05  sin precipitaciones      13.064264
# 1       1012.456250   -6.860000e-07  sin precipitaciones      12.453210
# 2       1012.368125    6.660000e-07  sin precipitaciones      10.392664
# 3       1012.543125    1.220000e-06  sin precipitaciones       8.273584
# 4       1012.673750    1.130000e-06  sin precipitaciones       7.544336
# 5       1012.659375    2.290000e-06  sin precipitaciones       6.913049
# 6       1012.491250    3.490000e-06  sin precipitaciones       6.220911
# 7       1012.315000    2.970000e-06  sin precipitaciones       5.943872
# 8       1012.189375    3.070000e-06  sin precipitaciones       5.993433
# 9       1011.985000    2.480000e-06  sin precipitaciones       5.963464
#
#    agua_del_suelo  nubosidad  precip_acum_x_hora  angulo_viento  dir_viento  \
# 0        0.137127   0.152496                 0.0             89        este
# 1        0.137084   0.236725                 0.0             76        este
# 2        0.137066   0.579987                 0.0             81        este
# 3        0.137028   0.482239                 0.0            105        este
# 4        0.137005   0.411499                 0.0            152     sureste
# 5        0.136968   0.614685                 0.0            172         sur
# 6        0.136947   0.535614                 0.0            188         sur
# 7        0.136921   0.141052                 0.0            209    sudoeste
# 8        0.136891   0.577209                 0.0            234    sudoeste
# 9        0.136874   0.652557                 0.0            237    sudoeste
#
#   vel_viento
# 0   1.669412
# 1   2.006793
# 2   1.787847
# 3   1.486212
# 4   1.950623
# 5   2.582033
# 6   2.653473
# 7   2.393420
# 8   2.003000
# 9   1.817661
#
# [10 rows x 21 columns]

# %%
datajuarez.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209424 entries, 0 to 209423
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ubicacion             209424 non-null  object
#  1   fecha                 209424 non-null  object
#  2   viento_U              209424 non-null  float64
#  3   viento_V              209424 non-null  float64
#  4   pto_rocio             209424 non-null  float64
#  5   tem_viento            209424 non-null  float64
#  6   alt_nube              109498 non-null  float64
#  7   evaporacion           209424 non-null  float64
#  8   rafaga_viento         209424 non-null  float64
#  9   evap_media            209424 non-null  float64
#  10  evap_media_potencial  209424 non-null  float64
#  11  pm_nivel_del_mar      209424 non-null  float64
#  12  evap_potencial        209424 non-null  float64
#  13  tip_precipitacion     209424 non-null  object
#  14  temp_del_suelo        209424 non-null  float64
#  15  agua_del_suelo        209424 non-null  float64
#  16  nubosidad             209424 non-null  float64
#  17  precip_acum_x_hora    209424 non-null  float64
#  18  angulo_viento         209424 non-null  int64
#  19  dir_viento            209424 non-null  object
#  20  vel_viento            209424 non-null  float64
# dtypes: float64(16), int64(1), object(4)
# memory usage: 33.6+ MB

# %% [markdown]
# Oservaciones:
# 1. Podemos decir que, no hay columnas irrelenvantes.
# 2. Pero en el caso de la columnas [**location/ubicacion**], la podemos remover, pues damos por sentado que, todo el dataset es solo de esta ubicación [*Ciudad Juárez*]
# 3. Por ende, considero que, podemos removerla sin afectar el dataset.

# %%
# Quitando columnas irrelevantes
col_irrelevante=['ubicacion']
datajuarez=datajuarez.drop(col_irrelevante, axis=1)
print("Dataset despues de quitar columanas irrelevantes:\n")
print(datajuarez.shape)
datajuarez.head(10)
# Out:
# Dataset despues de quitar columanas irrelevantes:
#
# (209424, 20)
#         fecha  viento_U  viento_V  pto_rocio  tem_viento     alt_nube  \
# 0  01/01/2000 -1.669281 -0.020920   7.480493   17.317834  1907.450439
# 1  01/01/2000 -1.951294 -0.468689   8.055566   16.767297  2135.849121
# 2  01/01/2000 -1.763443 -0.294388   5.953119   14.243799  2208.853027
# 3  01/01/2000 -1.436081  0.382751   5.892938   11.471796  7484.599609
# 4  01/01/2000 -0.908798  1.725983   5.761438   11.316980          NaN
# 5  01/01/2000 -0.377380  2.554306   5.132959    9.031458          NaN
# 6  01/01/2000  0.356659  2.629395   4.263757    7.635492          NaN
# 7  01/01/2000  1.176437  2.084335   3.994012    7.308130  2290.968262
# 8  01/01/2000  1.626434  1.169067   4.224725    7.595605  2288.184326
# 9  01/01/2000  1.527802  0.984741   4.503931    7.604150  2202.159912
#
#     evaporacion  rafaga_viento    evap_media  evap_media_potencial  \
# 0 -7.220000e-06       2.148321 -2.000000e-06         -3.470000e-06
# 1 -1.550000e-06       2.747254 -4.300000e-07         -1.910000e-07
# 2 -4.540000e-07       2.561296 -1.230000e-07          1.860000e-07
# 3  3.110000e-07       2.200583  8.660000e-08          3.350000e-07
# 4  6.010000e-07       2.526732  1.660000e-07          3.180000e-07
# 5  1.440000e-06       3.777871  3.940000e-07          6.380000e-07
# 6  2.260000e-06       4.538428  6.250000e-07          9.710000e-07
# 7  1.700000e-06       4.661475  4.710000e-07          8.200000e-07
# 8  2.120000e-06       4.536755  5.900000e-07          8.530000e-07
# 9  1.690000e-06       4.077042  4.710000e-07          6.850000e-07
#
#    pm_nivel_del_mar  evap_potencial    tip_precipitacion  temp_del_suelo  \
# 0       1012.635625   -1.250000e-05  sin precipitaciones       13.064264
# 1       1012.456250   -6.860000e-07  sin precipitaciones       12.453210
# 2       1012.368125    6.660000e-07  sin precipitaciones       10.392664
# 3       1012.543125    1.220000e-06  sin precipitaciones        8.273584
# 4       1012.673750    1.130000e-06  sin precipitaciones        7.544336
# 5       1012.659375    2.290000e-06  sin precipitaciones        6.913049
# 6       1012.491250    3.490000e-06  sin precipitaciones        6.220911
# 7       1012.315000    2.970000e-06  sin precipitaciones        5.943872
# 8       1012.189375    3.070000e-06  sin precipitaciones        5.993433
# 9       1011.985000    2.480000e-06  sin precipitaciones        5.963464
#
#    agua_del_suelo  nubosidad  precip_acum_x_hora  angulo_viento dir_viento  \
# 0        0.137127   0.152496                 0.0             89       este
# 1        0.137084   0.236725                 0.0             76       este
# 2        0.137066   0.579987                 0.0             81       este
# 3        0.137028   0.482239                 0.0            105       este
# 4        0.137005   0.411499                 0.0            152    sureste
# 5        0.136968   0.614685                 0.0            172        sur
# 6        0.136947   0.535614                 0.0            188        sur
# 7        0.136921   0.141052                 0.0            209   sudoeste
# 8        0.136891   0.577209                 0.0            234   sudoeste
# 9        0.136874   0.652557                 0.0            237   sudoeste
#
#    vel_viento
# 0    1.669412
# 1    2.006793
# 2    1.787847
# 3    1.486212
# 4    1.950623
# 5    2.582033
# 6    2.653473
# 7    2.393420
# 8    2.003000
# 9    1.817661

# %% [markdown]
# ## 4.3 Manejo de datos faltantes
# No hay celdas/filas con datos faltantes, es decir, que estan vacias, en su lugar esta el "valor: NaN", el cual si hay podemos ver a simple vista cuando datos un vistazo al dataframe.

# %%
#datajuarez.head(10)
# Haremos un conteo de NaN
valores_NaN = datajuarez.isna().sum()
print("Valores NaN:\n", valores_NaN)
# Out:
# Valores NaN:
#  fecha                       0
# viento_U                    0
# viento_V                    0
# pto_rocio                   0
# tem_viento                  0
# alt_nube                99926
# evaporacion                 0
# rafaga_viento               0
# evap_media                  0
# evap_media_potencial        0
# pm_nivel_del_mar            0
# evap_potencial              0
# tip_precipitacion           0
# temp_del_suelo              0
# agua_del_suelo              0
# nubosidad                   0
# precip_acum_x_hora          0
# angulo_viento               0
# dir_viento                  0
# vel_viento                  0
# dtype: int64

# %% [markdown]
# El manejo de NaN, sera reemplazada por el promedio de la columna en cuestion [*altura de la nube*]

# %%
# Convertir la columna a numerica, dando en NaN los valores no convertibles
datajuarez['alt_nube'] = pd.to_numeric(
    datajuarez['alt_nube'], errors='coerce')

# Calcular el promedio de la columna
promedio = datajuarez['alt_nube'].mean()
print(f"Promedio: ", promedio)
# datajuarez = datajuarez.apply(lambda col: col.replace(0,col.mean()), axis=0)
# Reemplazar NaN por el promedio de la columna
datajuarez['alt_nube'] = datajuarez['alt_nube'].fillna(promedio)

print("Dataframe despues del reemplazo de los valores NaN:\n")
datajuarez.head(10)
# Out:
# Promedio:  4100.22523477793
# Dataframe despues del reemplazo de los valores NaN:
#         fecha  viento_U  viento_V  pto_rocio  tem_viento     alt_nube  \
# 0  01/01/2000 -1.669281 -0.020920   7.480493   17.317834  1907.450439
# 1  01/01/2000 -1.951294 -0.468689   8.055566   16.767297  2135.849121
# 2  01/01/2000 -1.763443 -0.294388   5.953119   14.243799  2208.853027
# 3  01/01/2000 -1.436081  0.382751   5.892938   11.471796  7484.599609
# 4  01/01/2000 -0.908798  1.725983   5.761438   11.316980  4100.225235
# 5  01/01/2000 -0.377380  2.554306   5.132959    9.031458  4100.225235
# 6  01/01/2000  0.356659  2.629395   4.263757    7.635492  4100.225235
# 7  01/01/2000  1.176437  2.084335   3.994012    7.308130  2290.968262
# 8  01/01/2000  1.626434  1.169067   4.224725    7.595605  2288.184326
# 9  01/01/2000  1.527802  0.984741   4.503931    7.604150  2202.159912
#
#     evaporacion  rafaga_viento    evap_media  evap_media_potencial  \
# 0 -7.220000e-06       2.148321 -2.000000e-06         -3.470000e-06
# 1 -1.550000e-06       2.747254 -4.300000e-07         -1.910000e-07
# 2 -4.540000e-07       2.561296 -1.230000e-07          1.860000e-07
# 3  3.110000e-07       2.200583  8.660000e-08          3.350000e-07
# 4  6.010000e-07       2.526732  1.660000e-07          3.180000e-07
# 5  1.440000e-06       3.777871  3.940000e-07          6.380000e-07
# 6  2.260000e-06       4.538428  6.250000e-07          9.710000e-07
# 7  1.700000e-06       4.661475  4.710000e-07          8.200000e-07
# 8  2.120000e-06       4.536755  5.900000e-07          8.530000e-07
# 9  1.690000e-06       4.077042  4.710000e-07          6.850000e-07
#
#    pm_nivel_del_mar  evap_potencial    tip_precipitacion  temp_del_suelo  \
# 0       1012.635625   -1.250000e-05  sin precipitaciones       13.064264
# 1       1012.456250   -6.860000e-07  sin precipitaciones       12.453210
# 2       1012.368125    6.660000e-07  sin precipitaciones       10.392664
# 3       1012.543125    1.220000e-06  sin precipitaciones        8.273584
# 4       1012.673750    1.130000e-06  sin precipitaciones        7.544336
# 5       1012.659375    2.290000e-06  sin precipitaciones        6.913049
# 6       1012.491250    3.490000e-06  sin precipitaciones        6.220911
# 7       1012.315000    2.970000e-06  sin precipitaciones        5.943872
# 8       1012.189375    3.070000e-06  sin precipitaciones        5.993433
# 9       1011.985000    2.480000e-06  sin precipitaciones        5.963464
#
#    agua_del_suelo  nubosidad  precip_acum_x_hora  angulo_viento dir_viento  \
# 0        0.137127   0.152496                 0.0             89       este
# 1        0.137084   0.236725                 0.0             76       este
# 2        0.137066   0.579987                 0.0             81       este
# 3        0.137028   0.482239                 0.0            105       este
# 4        0.137005   0.411499                 0.0            152    sureste
# 5        0.136968   0.614685                 0.0            172        sur
# 6        0.136947   0.535614                 0.0            188        sur
# 7        0.136921   0.141052                 0.0            209   sudoeste
# 8        0.136891   0.577209                 0.0            234   sudoeste
# 9        0.136874   0.652557                 0.0            237   sudoeste
#
#    vel_viento
# 0    1.669412
# 1    2.006793
# 2    1.787847
# 3    1.486212
# 4    1.950623
# 5    2.582033
# 6    2.653473
# 7    2.393420
# 8    2.003000
# 9    1.817661

# %%
datajuarez.head(10)
# Haremos un conteo de NaN
valores_NaN = datajuarez.isna().sum()
print("Valores NaN:\n", valores_NaN)
# Out:
# Valores NaN:
#  fecha                   0
# viento_U                0
# viento_V                0
# pto_rocio               0
# tem_viento              0
# alt_nube                0
# evaporacion             0
# rafaga_viento           0
# evap_media              0
# evap_media_potencial    0
# pm_nivel_del_mar        0
# evap_potencial          0
# tip_precipitacion       0
# temp_del_suelo          0
# agua_del_suelo          0
# nubosidad               0
# precip_acum_x_hora      0
# angulo_viento           0
# dir_viento              0
# vel_viento              0
# dtype: int64

# %% [markdown]
# ## 4.4 Filas repetidas

# %%
print(datajuarez.shape)
datajuarez.head(10)
# Out:
# (209424, 20)
#         fecha  viento_U  viento_V  pto_rocio  tem_viento     alt_nube  \
# 0  01/01/2000 -1.669281 -0.020920   7.480493   17.317834  1907.450439
# 1  01/01/2000 -1.951294 -0.468689   8.055566   16.767297  2135.849121
# 2  01/01/2000 -1.763443 -0.294388   5.953119   14.243799  2208.853027
# 3  01/01/2000 -1.436081  0.382751   5.892938   11.471796  7484.599609
# 4  01/01/2000 -0.908798  1.725983   5.761438   11.316980  4100.225235
# 5  01/01/2000 -0.377380  2.554306   5.132959    9.031458  4100.225235
# 6  01/01/2000  0.356659  2.629395   4.263757    7.635492  4100.225235
# 7  01/01/2000  1.176437  2.084335   3.994012    7.308130  2290.968262
# 8  01/01/2000  1.626434  1.169067   4.224725    7.595605  2288.184326
# 9  01/01/2000  1.527802  0.984741   4.503931    7.604150  2202.159912
#
#     evaporacion  rafaga_viento    evap_media  evap_media_potencial  \
# 0 -7.220000e-06       2.148321 -2.000000e-06         -3.470000e-06
# 1 -1.550000e-06       2.747254 -4.300000e-07         -1.910000e-07
# 2 -4.540000e-07       2.561296 -1.230000e-07          1.860000e-07
# 3  3.110000e-07       2.200583  8.660000e-08          3.350000e-07
# 4  6.010000e-07       2.526732  1.660000e-07          3.180000e-07
# 5  1.440000e-06       3.777871  3.940000e-07          6.380000e-07
# 6  2.260000e-06       4.538428  6.250000e-07          9.710000e-07
# 7  1.700000e-06       4.661475  4.710000e-07          8.200000e-07
# 8  2.120000e-06       4.536755  5.900000e-07          8.530000e-07
# 9  1.690000e-06       4.077042  4.710000e-07          6.850000e-07
#
#    pm_nivel_del_mar  evap_potencial    tip_precipitacion  temp_del_suelo  \
# 0       1012.635625   -1.250000e-05  sin precipitaciones       13.064264
# 1       1012.456250   -6.860000e-07  sin precipitaciones       12.453210
# 2       1012.368125    6.660000e-07  sin precipitaciones       10.392664
# 3       1012.543125    1.220000e-06  sin precipitaciones        8.273584
# 4       1012.673750    1.130000e-06  sin precipitaciones        7.544336
# 5       1012.659375    2.290000e-06  sin precipitaciones        6.913049
# 6       1012.491250    3.490000e-06  sin precipitaciones        6.220911
# 7       1012.315000    2.970000e-06  sin precipitaciones        5.943872
# 8       1012.189375    3.070000e-06  sin precipitaciones        5.993433
# 9       1011.985000    2.480000e-06  sin precipitaciones        5.963464
#
#    agua_del_suelo  nubosidad  precip_acum_x_hora  angulo_viento dir_viento  \
# 0        0.137127   0.152496                 0.0             89       este
# 1        0.137084   0.236725                 0.0             76       este
# 2        0.137066   0.579987                 0.0             81       este
# 3        0.137028   0.482239                 0.0            105       este
# 4        0.137005   0.411499                 0.0            152    sureste
# 5        0.136968   0.614685                 0.0            172        sur
# 6        0.136947   0.535614                 0.0            188        sur
# 7        0.136921   0.141052                 0.0            209   sudoeste
# 8        0.136891   0.577209                 0.0            234   sudoeste
# 9        0.136874   0.652557                 0.0            237   sudoeste
#
#    vel_viento
# 0    1.669412
# 1    2.006793
# 2    1.787847
# 3    1.486212
# 4    1.950623
# 5    2.582033
# 6    2.653473
# 7    2.393420
# 8    2.003000
# 9    1.817661

# %%
print(f"Dataset antes de quitar duplicados: [{datajuarez.shape}]")
datajuarez.drop_duplicates(inplace=True)
print(f"Dataset despues de quitar duplicados: [{datajuarez.shape}]")
# Out:
# Dataset antes de quitar duplicados: [(209424, 20)]
# Dataset despues de quitar duplicados: [(209424, 20)]

# %% [markdown]
# ## 4.5 Outliers (*valores extremos*)

# %%
datajuarez.describe()
# Out:
#             viento_U       viento_V      pto_rocio     tem_viento  \
# count  209424.000000  209424.000000  209424.000000  209424.000000
# mean        0.370038       0.509397       1.636508      18.807033
# std         3.235571       1.608619       8.590113       9.812463
# min       -11.340240      -9.080811     -29.034842     -16.444403
# 25%        -1.902061      -0.491474      -4.939200      11.158350
# 50%         0.252632       0.550819       0.650781      19.598199
# 75%         2.425674       1.522297       8.666864      26.421793
# max        15.362930      11.523743      24.166284      42.485254
#
#             alt_nube    evaporacion  rafaga_viento    evap_media  \
# count  209424.000000  209424.000000  209424.000000  2.094240e+05
# mean     4100.225235      -0.000020       6.380918 -5.647070e-06
# std      1894.881206       0.000051       3.369432  1.412564e-05
# min        27.896713      -0.000604       0.508076 -1.678530e-04
# 25%      3292.380371      -0.000013       3.850678 -3.730000e-06
# 50%      4100.225235      -0.000004       5.674859 -1.080000e-06
# 75%      4100.225235      -0.000001       8.262992 -3.030000e-07
# max     14467.818360       0.000016      31.927536  4.310000e-06
#
#        evap_media_potencial  pm_nivel_del_mar  evap_potencial  temp_del_suelo  \
# count         209424.000000     209424.000000   209424.000000   209424.000000
# mean              -0.000059       1014.235355       -0.000211       20.860411
# std                0.000072          6.077775        0.000258       11.913696
# min               -0.000312        989.825625       -0.001124      -13.263220
# 25%               -0.000107       1010.089375       -0.000385       11.429391
# 50%               -0.000017       1013.525000       -0.000060       20.848154
# 75%               -0.000003       1017.661406       -0.000012       28.987253
# max                0.000005       1042.341250        0.000017       53.994501
#
#        agua_del_suelo      nubosidad  precip_acum_x_hora  angulo_viento  \
# count   209424.000000  209424.000000       209424.000000  209424.000000
# mean         0.043263       0.311505            0.022371     183.193044
# std          0.044748       0.368586            0.160154      88.192662
# min         -0.004450       0.000000            0.000000       0.000000
# 25%          0.023953       0.000000            0.000000     104.000000
# 50%          0.029167       0.114899            0.000000     195.000000
# 75%          0.039132       0.619781            0.000000     260.000000
# max          0.384890       1.000000            7.702827     359.000000
#
#           vel_viento
# count  209424.000000
# mean        3.143997
# std         1.888974
# min         0.005129
# 25%         1.801986
# 50%         2.723756
# 75%         4.082880
# max        16.691450

# %%
col_numericas = ['viento_U', 'viento_V', 'pto_rocio', 'tem_viento', 'alt_nube', 'evaporacion','rafaga_viento', 'evap_media', 'evap_media_potencial',
                 'pm_nivel_del_mar', 'evap_potencial', 'temp_del_suelo','agua_del_suelo', 'nubosidad', 'precip_acum_x_hora', 'angulo_viento', 'vel_viento']

fig, ax = plt.subplots(nrows=17, ncols=1, figsize=(10, 25))
fig.subplots_adjust(hspace=0.5)

for i, col in enumerate(col_numericas):
    sns.boxplot(x=col, datajuarez=datajuarez, ax=ax[i])
    ax[i].set_title(col)
    ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\Proyectos\Python\CdJuarezMX_Historial_Forecast\notebooks\EDA\Etapa 2 - Analisis de los Datos.ipynb Cell 22 line 8
#       <a href='vscode-notebook-cell:/d%3A/Proyectos/Python/CdJuarezMX_Historial_Forecast/notebooks/EDA/Etapa%202%20-%20Analisis%20de%20los%20Datos.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a> fig.subplots_adjust(hspace=0.5)
#       <a href='vscode-notebook-cell:/d%3A/Proyectos/Python/CdJuarezMX_Historial_Forecast/notebooks/EDA/Etapa%202%20-%20Analisis%20de%20los%20Datos.ipynb#X35sZmlsZQ%3D%3D?line=6'>7</a> for i, col in enumerate(col_numericas):
# ----> <a href='vscode-notebook-cell:/d%3A/Proyectos/Python/CdJuarezMX_Historial_Forecast/notebooks/EDA/Etapa%202%20-%20Analisis%20de%20los%20Datos.ipynb#X35sZmlsZQ%3D%3D?line=7'>8</a>     sns.boxplot(x=col, datajuarez=datajuarez, ax=ax[i])
#       <a href='vscode-notebook-cell:/d%3A/Proyectos/Python/CdJuarezMX_Historial_Forecast/notebooks/EDA/Etapa%202%20-%20Analisis%20de%20los%20Datos.ipynb#X35sZmlsZQ%3D%3D?line=8'>9</a>     ax[i].set_title(col)
#      <a href='vscode-notebook-cell:/d%3A/Proyectos/Python/CdJuarezMX_Historial_Forecast/notebooks/EDA/Etapa%202%20-%20Analisis%20de%20los%20Datos.ipynb#X35sZmlsZQ%3D%3D?line=9'>10</a>     ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
#
# File d:\Proyectos\Python\CdJuarezMX_Historial_Forecast\cdjuarezforecast\Lib\site-packages\seaborn\categorical.py:1582, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1574 def boxplot(
#    1575     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1576     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1579     legend="auto", ax=None, **kwargs
#    1580 ):
# -> 1582     p = _CategoricalPlotter(
#    1583         data=data,
#    1584         variables=dict(x=x, y=y, hue=hue),
#    1585         order=order,
#    1586         orient=orient,
#    1587         color=color,
#    1588         legend=legend,
#    1589     )
#    1591     if ax is None:
#    1592         ax = plt.gca()
#
# File d:\Proyectos\Python\CdJuarezMX_Historial_Forecast\cdjuarezforecast\Lib\site-packages\seaborn\categorical.py:62, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      51 def __init__(
#      52     self,
#      53     data=None,
#    (...)
#      59     legend="auto",
#      60 ):
# ---> 62     super().__init__(data=data, variables=variables)
#      64     # This method takes care of some bookkeeping that is necessary because the
#      65     # original categorical plots (prior to the 2021 refactor) had some rules that
#      66     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)
#      71     # default VectorPlotter rules. If we do decide to make orient part of the
#      72     # _base variable assignment, we'll want to figure out how to express that.
#      73     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File d:\Proyectos\Python\CdJuarezMX_Historial_Forecast\cdjuarezforecast\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File d:\Proyectos\Python\CdJuarezMX_Historial_Forecast\cdjuarezforecast\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File d:\Proyectos\Python\CdJuarezMX_Historial_Forecast\cdjuarezforecast\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File d:\Proyectos\Python\CdJuarezMX_Historial_Forecast\cdjuarezforecast\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `viento_U` for `x`. Value is a string, but `data` was not passed.

# %% [markdown]
# ## 4.6 Exportando nuevo dataset
