# %% [markdown]
# # 3. Visualización de los datos

# %%
# Lectura del dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Lectura del CSV
ruta_csv="..//../csv/WHData_Cd_Juarez.csv"

# Leyendo CSV con Pandas
datajuarez=pd.read_csv(ruta_csv, encoding='latin-1')

#Mostra dataframe
print(datajuarez.shape)
datajuarez.head(10)
# Out:
# (209424, 26)
#             name        lat         lon       time             time_iso  \
# 0  Ciudad Juarez  31.709839 -106.462102  946684800  2000-01-01T00:00:00
# 1  Ciudad Juarez  31.709839 -106.462102  946688400  2000-01-01T01:00:00
# 2  Ciudad Juarez  31.709839 -106.462102  946692000  2000-01-01T02:00:00
# 3  Ciudad Juarez  31.709839 -106.462102  946695600  2000-01-01T03:00:00
# 4  Ciudad Juarez  31.709839 -106.462102  946699200  2000-01-01T04:00:00
# 5  Ciudad Juarez  31.709839 -106.462102  946702800  2000-01-01T05:00:00
# 6  Ciudad Juarez  31.709839 -106.462102  946706400  2000-01-01T06:00:00
# 7  Ciudad Juarez  31.709839 -106.462102  946710000  2000-01-01T07:00:00
# 8  Ciudad Juarez  31.709839 -106.462102  946713600  2000-01-01T08:00:00
# 9  Ciudad Juarez  31.709839 -106.462102  946717200  2000-01-01T09:00:00
#
#      time_usa  time_num_usa     v_10u     v_10v      v_2d  ...        v_msl  \
# 0  01/01/2000         36526 -1.669281 -0.020920  7.480493  ...  1012.635625
# 1  01/01/2000         36526 -1.951294 -0.468689  8.055566  ...  1012.456250
# 2  01/01/2000         36526 -1.763443 -0.294388  5.953119  ...  1012.368125
# 3  01/01/2000         36526 -1.436081  0.382751  5.892938  ...  1012.543125
# 4  01/01/2000         36526 -0.908798  1.725983  5.761438  ...  1012.673750
# 5  01/01/2000         36526 -0.377380  2.554306  5.132959  ...  1012.659375
# 6  01/01/2000         36526  0.356659  2.629395  4.263757  ...  1012.491250
# 7  01/01/2000         36526  1.176437  2.084335  3.994012  ...  1012.315000
# 8  01/01/2000         36526  1.626434  1.169067  4.224725  ...  1012.189375
# 9  01/01/2000         36526  1.527802  0.984741  4.503931  ...  1011.985000
#
#           v_pev  v_ptype     v_stl1   v_swvl1     v_tcc  v_tp  v_wa      v_wd  \
# 0 -1.250000e-05        0  13.064264  0.137127  0.152496   0.0    89      este
# 1 -6.860000e-07        0  12.453210  0.137084  0.236725   0.0    76      este
# 2  6.660000e-07        0  10.392664  0.137066  0.579987   0.0    81      este
# 3  1.220000e-06        0   8.273584  0.137028  0.482239   0.0   105      este
# 4  1.130000e-06        0   7.544336  0.137005  0.411499   0.0   152   sureste
# 5  2.290000e-06        0   6.913049  0.136968  0.614685   0.0   172       sur
# 6  3.490000e-06        0   6.220911  0.136947  0.535614   0.0   188       sur
# 7  2.970000e-06        0   5.943872  0.136921  0.141052   0.0   209  sudoeste
# 8  3.070000e-06        0   5.993433  0.136891  0.577209   0.0   234  sudoeste
# 9  2.480000e-06        0   5.963464  0.136874  0.652557   0.0   237  sudoeste
#
#        v_ws
# 0  1.669412
# 1  2.006793
# 2  1.787847
# 3  1.486212
# 4  1.950623
# 5  2.582033
# 6  2.653473
# 7  2.393420
# 8  2.003000
# 9  1.817661
#
# [10 rows x 26 columns]

# %% [markdown]
# # 4. Limpieza
# En este apartado se realiza la limpieza del dataset, se realizaran:
#
# 1. Reemplazo de valores, si es que lo necesitan.
# 2. Tranformar valores para que sean comprensibles.
# 2. Reemplazo de las cabeceras, si es que lo necesitan.

# %%
# Reemplzando titulos de las cabeceras para hacerlos mas legibles
nuevos_titulos = {'name': 'ubicacion',
                  'lat': 'latitud',
                  'lon': 'longitud',
                  'time': 'tiempo',
                  'time_iso': 'tiempo_iso',
                  'time_usa': 'tiempo_americano',
                  'time__num_usa': 'tiempo_num_americano',
                  'v_10u': 'viento_U',
                  'v_10v': 'viento_V',
                  'v_2d': 'pto_rocio',
                  'v_2t': 'tem_viento',
                  'v_cbh': 'alt_nube',
                  'v_e': 'evaporacion',
                  'v_i10fg': 'rafaga_viento',
                  'v_mer': 'evap_media',
                  'v_mper': 'evap_media_potencial',
                  'v_msl': 'pm_nivel_del_mar',
                  'v_pev': 'evap_potencial',
                  'v_ptype': 'tip_precipitacion',
                  'v_stl1': 'temp_del_suelo',
                  'v_swvl1': 'agua_del_suelo',
                  'v_tcc': 'nubosidad',
                  'v_tp': 'precip_acum_x_hora',
                  'v_wa': 'angulo_viento',
                  'v_wd': 'dir_viento',
                  'v_ws': 'vel_viento'}

print("Dataframe nueva cabecera:\n")
datajuarez = datajuarez.rename(columns=nuevos_titulos)
datajuarez.head(10)
# Out:
# Dataframe nueva cabecera:
#        ubicacion    latitud    longitud     tiempo           tiempo_iso  \
# 0  Ciudad Juarez  31.709839 -106.462102  946684800  2000-01-01T00:00:00
# 1  Ciudad Juarez  31.709839 -106.462102  946688400  2000-01-01T01:00:00
# 2  Ciudad Juarez  31.709839 -106.462102  946692000  2000-01-01T02:00:00
# 3  Ciudad Juarez  31.709839 -106.462102  946695600  2000-01-01T03:00:00
# 4  Ciudad Juarez  31.709839 -106.462102  946699200  2000-01-01T04:00:00
# 5  Ciudad Juarez  31.709839 -106.462102  946702800  2000-01-01T05:00:00
# 6  Ciudad Juarez  31.709839 -106.462102  946706400  2000-01-01T06:00:00
# 7  Ciudad Juarez  31.709839 -106.462102  946710000  2000-01-01T07:00:00
# 8  Ciudad Juarez  31.709839 -106.462102  946713600  2000-01-01T08:00:00
# 9  Ciudad Juarez  31.709839 -106.462102  946717200  2000-01-01T09:00:00
#
#   tiempo_americano  time_num_usa  viento_U  viento_V  pto_rocio  ...  \
# 0       01/01/2000         36526 -1.669281 -0.020920   7.480493  ...
# 1       01/01/2000         36526 -1.951294 -0.468689   8.055566  ...
# 2       01/01/2000         36526 -1.763443 -0.294388   5.953119  ...
# 3       01/01/2000         36526 -1.436081  0.382751   5.892938  ...
# 4       01/01/2000         36526 -0.908798  1.725983   5.761438  ...
# 5       01/01/2000         36526 -0.377380  2.554306   5.132959  ...
# 6       01/01/2000         36526  0.356659  2.629395   4.263757  ...
# 7       01/01/2000         36526  1.176437  2.084335   3.994012  ...
# 8       01/01/2000         36526  1.626434  1.169067   4.224725  ...
# 9       01/01/2000         36526  1.527802  0.984741   4.503931  ...
#
#    pm_nivel_del_mar  evap_potencial  tip_precipitacion  temp_del_suelo  \
# 0       1012.635625   -1.250000e-05                  0       13.064264
# 1       1012.456250   -6.860000e-07                  0       12.453210
# 2       1012.368125    6.660000e-07                  0       10.392664
# 3       1012.543125    1.220000e-06                  0        8.273584
# 4       1012.673750    1.130000e-06                  0        7.544336
# 5       1012.659375    2.290000e-06                  0        6.913049
# 6       1012.491250    3.490000e-06                  0        6.220911
# 7       1012.315000    2.970000e-06                  0        5.943872
# 8       1012.189375    3.070000e-06                  0        5.993433
# 9       1011.985000    2.480000e-06                  0        5.963464
#
#    agua_del_suelo  nubosidad  precip_acum_x_hora  angulo_viento  dir_viento  \
# 0        0.137127   0.152496                 0.0             89        este
# 1        0.137084   0.236725                 0.0             76        este
# 2        0.137066   0.579987                 0.0             81        este
# 3        0.137028   0.482239                 0.0            105        este
# 4        0.137005   0.411499                 0.0            152     sureste
# 5        0.136968   0.614685                 0.0            172         sur
# 6        0.136947   0.535614                 0.0            188         sur
# 7        0.136921   0.141052                 0.0            209    sudoeste
# 8        0.136891   0.577209                 0.0            234    sudoeste
# 9        0.136874   0.652557                 0.0            237    sudoeste
#
#    vel_viento
# 0    1.669412
# 1    2.006793
# 2    1.787847
# 3    1.486212
# 4    1.950623
# 5    2.582033
# 6    2.653473
# 7    2.393420
# 8    2.003000
# 9    1.817661
#
# [10 rows x 26 columns]

# %% [markdown]
# ## 4.2 Columnas irrelevantes

# %%
print("Dimensiones del Dataframe:\n",datajuarez.shape)
datajuarez.head(10)
# Out:
# Dimensiones del Dataframe:
#  (209424, 26)
#        ubicacion    latitud    longitud     tiempo           tiempo_iso  \
# 0  Ciudad Juarez  31.709839 -106.462102  946684800  2000-01-01T00:00:00
# 1  Ciudad Juarez  31.709839 -106.462102  946688400  2000-01-01T01:00:00
# 2  Ciudad Juarez  31.709839 -106.462102  946692000  2000-01-01T02:00:00
# 3  Ciudad Juarez  31.709839 -106.462102  946695600  2000-01-01T03:00:00
# 4  Ciudad Juarez  31.709839 -106.462102  946699200  2000-01-01T04:00:00
# 5  Ciudad Juarez  31.709839 -106.462102  946702800  2000-01-01T05:00:00
# 6  Ciudad Juarez  31.709839 -106.462102  946706400  2000-01-01T06:00:00
# 7  Ciudad Juarez  31.709839 -106.462102  946710000  2000-01-01T07:00:00
# 8  Ciudad Juarez  31.709839 -106.462102  946713600  2000-01-01T08:00:00
# 9  Ciudad Juarez  31.709839 -106.462102  946717200  2000-01-01T09:00:00
#
#   tiempo_americano  time_num_usa  viento_U  viento_V  pto_rocio  ...  \
# 0       01/01/2000         36526 -1.669281 -0.020920   7.480493  ...
# 1       01/01/2000         36526 -1.951294 -0.468689   8.055566  ...
# 2       01/01/2000         36526 -1.763443 -0.294388   5.953119  ...
# 3       01/01/2000         36526 -1.436081  0.382751   5.892938  ...
# 4       01/01/2000         36526 -0.908798  1.725983   5.761438  ...
# 5       01/01/2000         36526 -0.377380  2.554306   5.132959  ...
# 6       01/01/2000         36526  0.356659  2.629395   4.263757  ...
# 7       01/01/2000         36526  1.176437  2.084335   3.994012  ...
# 8       01/01/2000         36526  1.626434  1.169067   4.224725  ...
# 9       01/01/2000         36526  1.527802  0.984741   4.503931  ...
#
#    pm_nivel_del_mar  evap_potencial  tip_precipitacion  temp_del_suelo  \
# 0       1012.635625   -1.250000e-05                  0       13.064264
# 1       1012.456250   -6.860000e-07                  0       12.453210
# 2       1012.368125    6.660000e-07                  0       10.392664
# 3       1012.543125    1.220000e-06                  0        8.273584
# 4       1012.673750    1.130000e-06                  0        7.544336
# 5       1012.659375    2.290000e-06                  0        6.913049
# 6       1012.491250    3.490000e-06                  0        6.220911
# 7       1012.315000    2.970000e-06                  0        5.943872
# 8       1012.189375    3.070000e-06                  0        5.993433
# 9       1011.985000    2.480000e-06                  0        5.963464
#
#    agua_del_suelo  nubosidad  precip_acum_x_hora  angulo_viento  dir_viento  \
# 0        0.137127   0.152496                 0.0             89        este
# 1        0.137084   0.236725                 0.0             76        este
# 2        0.137066   0.579987                 0.0             81        este
# 3        0.137028   0.482239                 0.0            105        este
# 4        0.137005   0.411499                 0.0            152     sureste
# 5        0.136968   0.614685                 0.0            172         sur
# 6        0.136947   0.535614                 0.0            188         sur
# 7        0.136921   0.141052                 0.0            209    sudoeste
# 8        0.136891   0.577209                 0.0            234    sudoeste
# 9        0.136874   0.652557                 0.0            237    sudoeste
#
#    vel_viento
# 0    1.669412
# 1    2.006793
# 2    1.787847
# 3    1.486212
# 4    1.950623
# 5    2.582033
# 6    2.653473
# 7    2.393420
# 8    2.003000
# 9    1.817661
#
# [10 rows x 26 columns]

# %% [markdown]
# Oservaciones:
# 1. Podemos decir que, no hay columnas irrelenvantes.
# 2. Pero en el caso de la columnas [**location/ubicacion**], la podemos remover, pues damos por sentado que, todo el dataset es solo de esta ubicación [*Ciudad Juárez*]
# 3. Por ende, considero que, podemos removerla sin afectar el dataset.

# %%
# Quitando columnas irrelevantes
col_irrelevante=['ubicacion','latitud','longitud','tiempo','tiempo_iso']
datajuarez=datajuarez.drop(col_irrelevante, axis=1)
print("Dataset despues de quitar columanas irrelevantes:\n")
print(datajuarez.shape)
datajuarez.head(10)
# Out:
# Dataset despues de quitar columanas irrelevantes:
#
# (209424, 21)
#   tiempo_americano  time_num_usa  viento_U  viento_V  pto_rocio  tem_viento  \
# 0       01/01/2000         36526 -1.669281 -0.020920   7.480493   17.317834
# 1       01/01/2000         36526 -1.951294 -0.468689   8.055566   16.767297
# 2       01/01/2000         36526 -1.763443 -0.294388   5.953119   14.243799
# 3       01/01/2000         36526 -1.436081  0.382751   5.892938   11.471796
# 4       01/01/2000         36526 -0.908798  1.725983   5.761438   11.316980
# 5       01/01/2000         36526 -0.377380  2.554306   5.132959    9.031458
# 6       01/01/2000         36526  0.356659  2.629395   4.263757    7.635492
# 7       01/01/2000         36526  1.176437  2.084335   3.994012    7.308130
# 8       01/01/2000         36526  1.626434  1.169067   4.224725    7.595605
# 9       01/01/2000         36526  1.527802  0.984741   4.503931    7.604150
#
#       alt_nube   evaporacion  rafaga_viento    evap_media  ...  \
# 0  1907.450439 -7.220000e-06       2.148321 -2.000000e-06  ...
# 1  2135.849121 -1.550000e-06       2.747254 -4.300000e-07  ...
# 2  2208.853027 -4.540000e-07       2.561296 -1.230000e-07  ...
# 3  7484.599609  3.110000e-07       2.200583  8.660000e-08  ...
# 4  4100.225235  6.010000e-07       2.526732  1.660000e-07  ...
# 5  4100.225235  1.440000e-06       3.777871  3.940000e-07  ...
# 6  4100.225235  2.260000e-06       4.538428  6.250000e-07  ...
# 7  2290.968262  1.700000e-06       4.661475  4.710000e-07  ...
# 8  2288.184326  2.120000e-06       4.536755  5.900000e-07  ...
# 9  2202.159912  1.690000e-06       4.077042  4.710000e-07  ...
#
#    pm_nivel_del_mar  evap_potencial  tip_precipitacion  temp_del_suelo  \
# 0       1012.635625   -1.250000e-05                  0       13.064264
# 1       1012.456250   -6.860000e-07                  0       12.453210
# 2       1012.368125    6.660000e-07                  0       10.392664
# 3       1012.543125    1.220000e-06                  0        8.273584
# 4       1012.673750    1.130000e-06                  0        7.544336
# 5       1012.659375    2.290000e-06                  0        6.913049
# 6       1012.491250    3.490000e-06                  0        6.220911
# 7       1012.315000    2.970000e-06                  0        5.943872
# 8       1012.189375    3.070000e-06                  0        5.993433
# 9       1011.985000    2.480000e-06                  0        5.963464
#
#    agua_del_suelo  nubosidad  precip_acum_x_hora  angulo_viento  dir_viento  \
# 0        0.137127   0.152496                 0.0             89        este
# 1        0.137084   0.236725                 0.0             76        este
# 2        0.137066   0.579987                 0.0             81        este
# 3        0.137028   0.482239                 0.0            105        este
# 4        0.137005   0.411499                 0.0            152     sureste
# 5        0.136968   0.614685                 0.0            172         sur
# 6        0.136947   0.535614                 0.0            188         sur
# 7        0.136921   0.141052                 0.0            209    sudoeste
# 8        0.136891   0.577209                 0.0            234    sudoeste
# 9        0.136874   0.652557                 0.0            237    sudoeste
#
#   vel_viento
# 0   1.669412
# 1   2.006793
# 2   1.787847
# 3   1.486212
# 4   1.950623
# 5   2.582033
# 6   2.653473
# 7   2.393420
# 8   2.003000
# 9   1.817661
#
# [10 rows x 21 columns]

# %% [markdown]
# ## 4.3 Manejo de datos faltantes

# %%
#datajuarez.head(10)
# Haremos un conteo de NaN
valores_NaN = datajuarez.isna().sum()
print("Valores NaN:\n", valores_NaN)
# Out:
# Valores NaN:
#  tiempo_americano        0
# time_num_usa            0
# viento_U                0
# viento_V                0
# pto_rocio               0
# tem_viento              0
# alt_nube                0
# evaporacion             0
# rafaga_viento           0
# evap_media              0
# evap_media_potencial    0
# pm_nivel_del_mar        0
# evap_potencial          0
# tip_precipitacion       0
# temp_del_suelo          0
# agua_del_suelo          0
# nubosidad               0
# precip_acum_x_hora      0
# angulo_viento           0
# dir_viento              0
# vel_viento              0
# dtype: int64

# %%
datajuarez.head(10)
# Haremos un conteo de NaN
valores_NaN = datajuarez.isna().sum()
print("Valores NaN:\n", valores_NaN)
# Out:
# Valores NaN:
#  tiempo_americano        0
# time_num_usa            0
# viento_U                0
# viento_V                0
# pto_rocio               0
# tem_viento              0
# alt_nube                0
# evaporacion             0
# rafaga_viento           0
# evap_media              0
# evap_media_potencial    0
# pm_nivel_del_mar        0
# evap_potencial          0
# tip_precipitacion       0
# temp_del_suelo          0
# agua_del_suelo          0
# nubosidad               0
# precip_acum_x_hora      0
# angulo_viento           0
# dir_viento              0
# vel_viento              0
# dtype: int64

# %% [markdown]
# ## 4.4 Filas repetidas

# %%
print(f"Dataset antes de quitar duplicados: [{datajuarez.shape}]")
datajuarez.drop_duplicates(inplace=True)
print(f"Dataset despues de quitar duplicados: [{datajuarez.shape}]")
# Out:
# Dataset antes de quitar duplicados: [(209424, 21)]
# Dataset despues de quitar duplicados: [(209424, 21)]

# %%
# Conversion de las columnas numericas a su formato numerico
#datajuarez['viento_U'] = datajuarez['viento_U'].astype(float)

# %% [markdown]
# ## 4.5 Outliers (*valores extremos*)

# %%
datajuarez.describe()
# Out:
#         time_num_usa       viento_U       viento_V      pto_rocio  \
# count  209424.000000  209424.000000  209424.000000  209424.000000
# mean    40888.500000       0.370038       0.509397       1.636508
# std      2518.985222       3.235571       1.608619       8.590113
# min     36526.000000     -11.340240      -9.080811     -29.034842
# 25%     38707.000000      -1.902061      -0.491474      -4.939200
# 50%     40888.500000       0.252632       0.550819       0.650781
# 75%     43070.000000       2.425674       1.522297       8.666864
# max     45251.000000      15.362930      11.523743      24.166284
#
#           tem_viento       alt_nube    evaporacion  rafaga_viento  \
# count  209424.000000  209424.000000  209424.000000  209424.000000
# mean       18.807033    4100.225235      -0.000020       6.380918
# std         9.812463    1894.881206       0.000051       3.369432
# min       -16.444403      27.896713      -0.000604       0.508076
# 25%        11.158350    3292.380371      -0.000013       3.850678
# 50%        19.598199    4100.225235      -0.000004       5.674859
# 75%        26.421793    4100.225235      -0.000001       8.262992
# max        42.485254   14467.818360       0.000016      31.927536
#
#          evap_media  evap_media_potencial  pm_nivel_del_mar  evap_potencial  \
# count  2.094240e+05         209424.000000     209424.000000   209424.000000
# mean  -5.647070e-06             -0.000059       1014.235355       -0.000211
# std    1.412564e-05              0.000072          6.077775        0.000258
# min   -1.678530e-04             -0.000312        989.825625       -0.001124
# 25%   -3.730000e-06             -0.000107       1010.089375       -0.000385
# 50%   -1.080000e-06             -0.000017       1013.525000       -0.000060
# 75%   -3.030000e-07             -0.000003       1017.661406       -0.000012
# max    4.310000e-06              0.000005       1042.341250        0.000017
#
#        tip_precipitacion  temp_del_suelo  agua_del_suelo      nubosidad  \
# count      209424.000000   209424.000000   209424.000000  209424.000000
# mean            0.107380       20.860411        0.043263       0.311505
# std             0.496105       11.913696        0.044748       0.368586
# min             0.000000      -13.263220       -0.004450       0.000000
# 25%             0.000000       11.429391        0.023953       0.000000
# 50%             0.000000       20.848154        0.029167       0.114899
# 75%             0.000000       28.987253        0.039132       0.619781
# max             8.000000       53.994501        0.384890       1.000000
#
#        precip_acum_x_hora  angulo_viento     vel_viento
# count       209424.000000  209424.000000  209424.000000
# mean             0.022371     183.193044       3.143997
# std              0.160154      88.192662       1.888974
# min              0.000000       0.000000       0.005129
# 25%              0.000000     104.000000       1.801986
# 50%              0.000000     195.000000       2.723756
# 75%              0.000000     260.000000       4.082880
# max              7.702827     359.000000      16.691450

# %%
datajuarez.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209424 entries, 0 to 209423
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   tiempo_americano      209424 non-null  object
#  1   time_num_usa          209424 non-null  int64
#  2   viento_U              209424 non-null  float64
#  3   viento_V              209424 non-null  float64
#  4   pto_rocio             209424 non-null  float64
#  5   tem_viento            209424 non-null  float64
#  6   alt_nube              209424 non-null  float64
#  7   evaporacion           209424 non-null  float64
#  8   rafaga_viento         209424 non-null  float64
#  9   evap_media            209424 non-null  float64
#  10  evap_media_potencial  209424 non-null  float64
#  11  pm_nivel_del_mar      209424 non-null  float64
#  12  evap_potencial        209424 non-null  float64
#  13  tip_precipitacion     209424 non-null  int64
#  14  temp_del_suelo        209424 non-null  float64
#  15  agua_del_suelo        209424 non-null  float64
#  16  nubosidad             209424 non-null  float64
#  17  precip_acum_x_hora    209424 non-null  float64
#  18  angulo_viento         209424 non-null  int64
#  19  dir_viento            209424 non-null  object
#  20  vel_viento            209424 non-null  float64
# dtypes: float64(16), int64(3), object(2)
# memory usage: 33.6+ MB

# %%
col_numericas = ['viento_U', 'viento_V', 'pto_rocio', 'tem_viento', 'alt_nube', 'evaporacion','rafaga_viento', 'evap_media', 'evap_media_potencial',
                 'pm_nivel_del_mar', 'evap_potencial', 'temp_del_suelo', 'agua_del_suelo','nubosidad', 'precip_acum_x_hora', 'angulo_viento', 'vel_viento']
fig, ax = plt.subplots(nrows=17, ncols=1, figsize=(10, 80))
fig.subplots_adjust(hspace=0.5)

for i, col in enumerate(col_numericas):
    sns.boxplot(x=col, data=datajuarez, ax=ax[i])
    ax[i].set_title(col)
    ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# Out:
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)
# C:\Users\josetorres\AppData\Local\Temp\ipykernel_20192\1231826003.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i].set_xticklabels(ax[i].get_xticklabels(), rotation=45)

# %% [markdown]
# ## 4.6 Exportando nuevo dataset

# %%
ruta="..//../results/WHCd_Juarez_clean_v1.csv"
datajuarez.to_csv(ruta, index=False)
